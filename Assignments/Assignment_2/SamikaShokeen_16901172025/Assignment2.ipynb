# %%
##print 10 nqtural number
s=0
for i in range(1,11):
  s+=i
print(s)
# Out:
# 55

# %%
## factorial
n=int(input("Number who's factorial you want:"))
f=1
for i in range(1,n+1):
  f*=i
print(f)
# Out:
# Number who's factorial you want:0
# 1

# %%
## fibonacci
a=1
b=1
c=1
n=int(input("enter range of fibonacci series"))
while b<n:
  print(c)
  a=b
  b=c
  c=a+b
# Out:
# enter range of fibonacci series7
# 1
# 2
# 3
# 5
# 8

# %%
## max of 3 numbers

p=int(input("enter number"))
m=int(input("enter number"))
n=int(input("enter number"))
l=max([p,m,n])
print(l)
# Out:
# Enter value45
# Enter value55
# Enter value66
# 66

# %%
## grading marks
l=int(input("enter marks"))
if l>=90:
    print("A")
elif l>=70: print("B")
elif l>50: print("C")
else:print("D")
# print()
# Out:
# enter marks88
# B
