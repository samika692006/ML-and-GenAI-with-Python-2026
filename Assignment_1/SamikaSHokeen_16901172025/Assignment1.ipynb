# %%
l=int(input("enter length"))
b=int(input("enter breadth"))
print('area:',l*b)
# Out:
# enter length10
# enter breadth15
# area: 150

# %%
p=int(input("enter Principle value"))
r=int(input("enter rate of interest"))
t=int(input("enter Time period"))
print("interest:"(p*r*t)/100)

# %%
c=int(input("Temperature in celcius"))
print("Temp in Farenheit",(c*9/5) + 32)
# Out:
# Temperature in celcius0
# Temp in Farenheit 32.0

# %%
n1=int(input("enter num1"))
n2=int(input("enter num2"))
n3=int(input("enter num3"))
print("Average",(n1+n2+n3)/3)

# %%
n=int(input("enter number"))
print("square of number:",n**2)
print("Cube of number:",n**3)

# %%
a=5
b=10
print(a,b)
a=a+b
b=a-b
a=a-b
print(a,b)
# Out:
# 5 10
# 10 5

# %%
student_name=input("name:")
marks_math=int(input("Marks in math"))
marks_English=int(input("marks in english"))
marks_science=int(input("marks in science"))
print(student_name)
print("Total:", marks_English+marks_math+marks_science)
# print("percentage:",(marks_English+marks_math+marks_science)/005)
# Out:
# name:AA
# Marks in math11
# marks in english45
# marks in science599
# AA
# Total: 655
